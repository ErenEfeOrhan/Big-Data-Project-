# %% [markdown]
# # Adım 7 - Dashboard ve Görselleştirilmiş Sonuçlar
#
# Bu notebook proje sunumu ve teslimi için ilgili adımı özetler.

# %% [markdown]
# ## Amaç
#
# EDA ve ML çıktılarını tek bir dashboard ekranında anlaşılır şekilde sunmak.

# %% [markdown]
# ## Dashboard Dosyaları
#
# - dashboard/index.html
# - dashboard/assets/eda
# - dashboard/assets/ml
# - dashboard/step6_regression_results.csv

# %% [markdown]
# ## Dashboard İçeriği
#
# - 5 model performans karşılaştırması
# - Feature importance grafiği
# - Actual vs Predicted grafikleri
# - Residual dağılım grafiği
# - Popularity dağılımı
# - Eksik değer analizi
# - Korelasyon matrisi
# - Genre analizi
# - Zaman serisi grafiği

# %% [markdown]
# ## Açma Komutu
#
# ```powershell
# start dashboard\index.html
# ```

# %% [markdown]
# ## Sunumda Anlatılacak Nokta
#
# Proje isterinde Databricks Dashboard veya alternatif görselleştirme aracı kabul edildiği için HTML tabanlı dashboard hazırlanmıştır. Matplotlib çıktıları bu dashboard altında birleştirilmiştir.
